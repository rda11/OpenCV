# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('computer-vision-with-python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('Computer-Vision-with-Python/DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap = 'gray')

# %%
plt.imshow(img_gray,cmap = 'magma')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_r = 0.8
h_r = 0.3

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_r,h_r)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (390, 1560, 3)

# %%
new_img = cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
cv2.imwrite('neww.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
